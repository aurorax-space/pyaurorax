# %% [markdown]
# # Imports

# %%
import aurorax
import datetime
import pandas as pd
import pprint

# %% [markdown]
# # Search

# %%
# set values
start_dt = datetime.datetime(2019, 1, 1, 0, 0, 0)
end_dt = datetime.datetime(2019, 1, 1, 23, 59, 59)
programs = ["swarm"]
platforms = ["swarma"]
instrument_types = ["footprint"]

# %%
# perform search
s = aurorax.ephemeris.search(start_dt,
                             end_dt,
                             programs=programs,
                             platforms=platforms,
                             instrument_types=instrument_types,
                             verbose=True)
# Out:
# [2021-06-04 13:13:02.554400] Search object created
# [2021-06-04 13:13:02.646403] Request submitted
# [2021-06-04 13:13:02.646403] Request ID: 8e37dc40-5998-4a32-89be-be1819608a21
# [2021-06-04 13:13:02.646403] Request details available at: http://api.aurorax.space/api/v1/ephemeris/requests/8e37dc40-5998-4a32-89be-be1819608a21
# [2021-06-04 13:13:02.646403] Waiting for data ...
# [2021-06-04 13:13:04.376732] Checking for data ...
# [2021-06-04 13:13:04.460800] Data is now available
# [2021-06-04 13:13:04.460800] Retrieving data ...
# [2021-06-04 13:13:05.184273] Retrieved 5.1 MB of data containing 1440 records

# %%
# output data as a pandas dataframe
ephemeris_data = [e.__dict__ for e in s.data]
df = pd.DataFrame(ephemeris_data)
df.sort_values("epoch")  # sort by the timestamp
# Out:
#                                             data_source               epoch  \
# 0     {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 00:00:00
# 1     {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 00:01:00
# 2     {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 00:02:00
# 3     {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 00:03:00
# 4     {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 00:04:00
# ...                                                 ...                 ...
# 1435  {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 23:55:00
# 1436  {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 23:56:00
# 1437  {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 23:57:00
# 1438  {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 23:58:00
# 1439  {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 23:59:00
#
#                                 location_geo  \
# 0      {'lat': -17.019026, 'lon': -136.0207}
# 1     {'lat': -13.168878, 'lon': -136.07999}
# 2      {'lat': -9.317859, 'lon': -136.14517}
# 3      {'lat': -5.466018, 'lon': -136.21439}
# 4      {'lat': -1.6134088, 'lon': -136.2859}
# ...                                      ...
# 1435     {'lat': 63.118088, 'lon': 39.44719}
# 1436    {'lat': 59.271484, 'lon': 39.970604}
# 1437     {'lat': 55.42148, 'lon': 40.336536}
# 1438    {'lat': 51.569214, 'lon': 40.592674}
# 1439     {'lat': 47.715435, 'lon': 40.76942}
#
#                                location_gsm  \
# 0       {'lat': 6.7606134, 'lon': 40.40137}
# 1       {'lat': 10.541506, 'lon': 41.12732}
# 2       {'lat': 14.321112, 'lon': 41.87248}
# 3       {'lat': 18.098713, 'lon': 42.64437}
# 4      {'lat': 21.873484, 'lon': 43.451508}
# ...                                     ...
# 1435  {'lat': 38.491505, 'lon': -150.19873}
# 1436  {'lat': 34.721504, 'lon': -149.17068}
# 1437  {'lat': 30.944128, 'lon': -148.23186}
# 1438  {'lat': 27.161028, 'lon': -147.36389}
# 1439  {'lat': 23.373522, 'lon': -146.55217}
#
#                                      nbtrace  \
# 0      {'lat': 14.933351, 'lon': -130.16835}
# 1      {'lat': 12.554154, 'lon': -131.52226}
# 2     {'lat': 10.6922245, 'lon': -132.69847}
# 3         {'lat': 9.6191, 'lon': -133.67313}
# 4       {'lat': 9.573847, 'lon': -134.42802}
# ...                                      ...
# 1435    {'lat': 63.825092, 'lon': 39.852196}
# 1436    {'lat': 60.096794, 'lon': 40.335415}
# 1437     {'lat': 56.37933, 'lon': 40.665756}
# 1438    {'lat': 52.677044, 'lon': 40.891216}
# 1439       {'lat': 48.9952, 'lon': 41.04236}
#
#                                      sbtrace  \
# 0     {'lat': -21.815926, 'lon': -137.23001}
# 1      {'lat': -19.18973, 'lon': -137.46463}
# 2     {'lat': -17.108786, 'lon': -137.80627}
# 3     {'lat': -15.831487, 'lon': -138.30301}
# 4     {'lat': -15.586076, 'lon': -139.00354}
# ...                                      ...
# 1435    {'lat': -52.62199, 'lon': 65.487434}
# 1436    {'lat': -48.855095, 'lon': 61.44911}
# 1437    {'lat': -44.895798, 'lon': 57.84364}
# 1438   {'lat': -40.812534, 'lon': 54.591457}
# 1439    {'lat': -36.66003, 'lon': 51.658134}
#
#                                                metadata
# 0     {'state': 'definitive', 'nbtrace_region': 'low...
# 1     {'state': 'definitive', 'nbtrace_region': 'low...
# 2     {'state': 'definitive', 'nbtrace_region': 'low...
# 3     {'state': 'definitive', 'nbtrace_region': 'low...
# 4     {'state': 'definitive', 'nbtrace_region': 'low...
# ...                                                 ...
# 1435  {'state': 'definitive', 'nbtrace_region': 'nor...
# 1436  {'state': 'definitive', 'nbtrace_region': 'nor...
# 1437  {'state': 'definitive', 'nbtrace_region': 'nor...
# 1438  {'state': 'definitive', 'nbtrace_region': 'nor...
# 1439  {'state': 'definitive', 'nbtrace_region': 'nor...
#
# [1440 rows x 7 columns]

# %% [markdown]
# # Do the search asynchonously
#
# Under the hood an ephemeris search is asynchronous. This adds some more complexity for the user, but also opens the search up to some additional possibilities. The main advantage is being able to perform queries for a large timeframe. These queries will take a bit longer and could exceed several minutes and return more than a gigabyte of data. Separating the request and the resulting data into two different API calls allows flexibility in duration and size of the overall request.

# %%
# set up the request
s = aurorax.ephemeris.Search(start_dt,
                             end_dt,
                             programs=programs,
                             platforms=platforms,
                             instrument_types=instrument_types)
print(s)
# Out:
# {'completed': False,
#  'data': [],
#  'data_url': '',
#  'end': datetime.datetime(2019, 1, 1, 23, 59, 59),
#  'executed': False,
#  'instrument_types': ['footprint'],
#  'logs': [],
#  'metadata_filters': None,
#  'platforms': ['swarma'],
#  'programs': ['swarm'],
#  'query': {},
#  'request': None,
#  'request_id': '',
#  'request_url': '',
#  'start': datetime.datetime(2019, 1, 1, 0, 0),
#  'status': {}}

# %%
# execute the search
s.execute()
print(s)
# Out:
# {'completed': False,
#  'data': [],
#  'data_url': '',
#  'end': datetime.datetime(2019, 1, 1, 23, 59, 59),
#  'executed': True,
#  'instrument_types': ['footprint'],
#  'logs': [],
#  'metadata_filters': None,
#  'platforms': ['swarma'],
#  'programs': ['swarm'],
#  'query': {'data_sources': {'ephemeris_metadata_filters': [],
#                             'instrument_types': ['footprint'],
#                             'platforms': ['swarma'],
#                             'programs': ['swarm']},
#            'end': '2019-01-01T23:59:59',
#            'start': '2019-01-01T00:00:00'},
#  'request': {'data': None, 'request': <Response [202]>, 'status_code': 202},
#  'request_id': 'f1c1cf81-c92e-4f1c-85e0-c1c1c6072b02',
#  'request_url': 'http://api.aurorax.space/api/v1/ephemeris/requests/f1c1cf81-c92e-4f1c-85e0-c1c1c6072b02',
#  'start': datetime.datetime(2019, 1, 1, 0, 0),
#  'status': {}}

# %%
# get request status
s.update_status()
pprint.pprint(s.status)
# Out:
# {'logs': [{'level': 'debug',
#            'summary': 'Search request arrived',
#            'timestamp': '2021-06-04T19:15:03.607011Z'},
#           {'level': 'debug',
#            'summary': 'Starting f1c1cf81-c92e-4f1c-85e0-c1c1c6072b02 for query '
#                       'Find ephemeris for (program in (swarm) AND platform in '
#                       '(swarma) AND instrument_type in (footprint) AND )  AND '
#                       'epoch between 2019-01-01T00:00 and 2019-01-01T23:59:59 '
#                       'UTC',
#            'timestamp': '2021-06-04T19:15:03.609966Z'},
#           {'level': 'info',
#            'summary': 'Finished query in 1.47 seconds.',
#            'timestamp': '2021-06-04T19:15:05.081667Z'},
#           {'level': 'debug',
#            'summary': 'Starting to write data to file',
#            'timestamp': '2021-06-04T19:15:05.085749Z'},
#           {'level': 'info',
#            'summary': 'Finished writing data, found 1440 records in 0.30 '
#                       'seconds.',
#            'timestamp': '2021-06-04T19:15:05.384239Z'},
#           {'level': 'debug',
#            'summary': 'File size is 5137225 bytes.',
#            'timestamp': '2021-06-04T19:15:05.387103Z'},
#           {'level': 'info',
#            'summary': 'Finished search in 1.78 seconds and found 1440 records.',
#            'timestamp': '2021-06-04T19:15:05.390437Z'}],
#  'search_request': {'query': {'data_sources': {'ephemeris_metadata_filters': [],
#                                                'instrument_types': ['footprint'],
#                                                'platforms': ['swarma'],
#                                                'programs': ['swarm']},
#                               'end': '2019-01-01T23:59:59',
#                               'start': '2019-01-01T00:00:00'},
#                     'request_id': 'f1c1cf81-c92e-4f1c-85e0-c1c1c6072b02',
#                     'request_type': 'ephemeris',
#                     'requested': '2021-06-04T19:15:03.461784Z',
#                     'user_uuid': None},
#  'search_result': {'completed_timestamp': '2021-06-04T19:15:05.388326Z',
#                    'data_uri': '/api/v1/ephemeris/requests/f1c1cf81-c92e-4f1c-85e0-c1c1c6072b02/data',
#                    'error_condition': False,
#                    'expiration_timestamp': '2021-06-09T19:15:05.387715Z',
#                    'file_size': 5137225,
#                    'query_duration': 1779,
#                    'result_count': 1440,
#                    'result_file_deleted_timestamp': None}}

# %%
# view just the logs for the request (update the status beforehand, but we do that in the above cell)
pprint.pprint(s.logs)
# Out:
# [{'level': 'debug',
#   'summary': 'Search request arrived',
#   'timestamp': '2021-06-04T19:15:03.607011Z'},
#  {'level': 'debug',
#   'summary': 'Starting f1c1cf81-c92e-4f1c-85e0-c1c1c6072b02 for query Find '
#              'ephemeris for (program in (swarm) AND platform in (swarma) AND '
#              'instrument_type in (footprint) AND )  AND epoch between '
#              '2019-01-01T00:00 and 2019-01-01T23:59:59 UTC',
#   'timestamp': '2021-06-04T19:15:03.609966Z'},
#  {'level': 'info',
#   'summary': 'Finished query in 1.47 seconds.',
#   'timestamp': '2021-06-04T19:15:05.081667Z'},
#  {'level': 'debug',
#   'summary': 'Starting to write data to file',
#   'timestamp': '2021-06-04T19:15:05.085749Z'},
#  {'level': 'info',
#   'summary': 'Finished writing data, found 1440 records in 0.30 seconds.',
#   'timestamp': '2021-06-04T19:15:05.384239Z'},
#  {'level': 'debug',
#   'summary': 'File size is 5137225 bytes.',
#   'timestamp': '2021-06-04T19:15:05.387103Z'},
#  {'level': 'info',
#   'summary': 'Finished search in 1.78 seconds and found 1440 records.',
#   'timestamp': '2021-06-04T19:15:05.390437Z'}]

# %%
# wait for the data
s.wait()
s.update_status()

# %%
# get data
s.get_data()

# show data as pandas dataframe
ephemeris_data = [e.__dict__ for e in s.data]
df = pd.DataFrame(ephemeris_data)
df.sort_values("epoch")  # sort by the timestamp
# Out:
#                                             data_source               epoch  \
# 0     {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 00:00:00
# 1     {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 00:01:00
# 2     {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 00:02:00
# 3     {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 00:03:00
# 4     {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 00:04:00
# ...                                                 ...                 ...
# 1435  {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 23:55:00
# 1436  {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 23:56:00
# 1437  {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 23:57:00
# 1438  {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 23:58:00
# 1439  {'data_product_metadata_schema': [],\n 'displa... 2019-01-01 23:59:00
#
#                                 location_geo  \
# 0      {'lat': -17.019026, 'lon': -136.0207}
# 1     {'lat': -13.168878, 'lon': -136.07999}
# 2      {'lat': -9.317859, 'lon': -136.14517}
# 3      {'lat': -5.466018, 'lon': -136.21439}
# 4      {'lat': -1.6134088, 'lon': -136.2859}
# ...                                      ...
# 1435     {'lat': 63.118088, 'lon': 39.44719}
# 1436    {'lat': 59.271484, 'lon': 39.970604}
# 1437     {'lat': 55.42148, 'lon': 40.336536}
# 1438    {'lat': 51.569214, 'lon': 40.592674}
# 1439     {'lat': 47.715435, 'lon': 40.76942}
#
#                                location_gsm  \
# 0       {'lat': 6.7606134, 'lon': 40.40137}
# 1       {'lat': 10.541506, 'lon': 41.12732}
# 2       {'lat': 14.321112, 'lon': 41.87248}
# 3       {'lat': 18.098713, 'lon': 42.64437}
# 4      {'lat': 21.873484, 'lon': 43.451508}
# ...                                     ...
# 1435  {'lat': 38.491505, 'lon': -150.19873}
# 1436  {'lat': 34.721504, 'lon': -149.17068}
# 1437  {'lat': 30.944128, 'lon': -148.23186}
# 1438  {'lat': 27.161028, 'lon': -147.36389}
# 1439  {'lat': 23.373522, 'lon': -146.55217}
#
#                                      nbtrace  \
# 0      {'lat': 14.933351, 'lon': -130.16835}
# 1      {'lat': 12.554154, 'lon': -131.52226}
# 2     {'lat': 10.6922245, 'lon': -132.69847}
# 3         {'lat': 9.6191, 'lon': -133.67313}
# 4       {'lat': 9.573847, 'lon': -134.42802}
# ...                                      ...
# 1435    {'lat': 63.825092, 'lon': 39.852196}
# 1436    {'lat': 60.096794, 'lon': 40.335415}
# 1437     {'lat': 56.37933, 'lon': 40.665756}
# 1438    {'lat': 52.677044, 'lon': 40.891216}
# 1439       {'lat': 48.9952, 'lon': 41.04236}
#
#                                      sbtrace  \
# 0     {'lat': -21.815926, 'lon': -137.23001}
# 1      {'lat': -19.18973, 'lon': -137.46463}
# 2     {'lat': -17.108786, 'lon': -137.80627}
# 3     {'lat': -15.831487, 'lon': -138.30301}
# 4     {'lat': -15.586076, 'lon': -139.00354}
# ...                                      ...
# 1435    {'lat': -52.62199, 'lon': 65.487434}
# 1436    {'lat': -48.855095, 'lon': 61.44911}
# 1437    {'lat': -44.895798, 'lon': 57.84364}
# 1438   {'lat': -40.812534, 'lon': 54.591457}
# 1439    {'lat': -36.66003, 'lon': 51.658134}
#
#                                                metadata
# 0     {'state': 'definitive', 'nbtrace_region': 'low...
# 1     {'state': 'definitive', 'nbtrace_region': 'low...
# 2     {'state': 'definitive', 'nbtrace_region': 'low...
# 3     {'state': 'definitive', 'nbtrace_region': 'low...
# 4     {'state': 'definitive', 'nbtrace_region': 'low...
# ...                                                 ...
# 1435  {'state': 'definitive', 'nbtrace_region': 'nor...
# 1436  {'state': 'definitive', 'nbtrace_region': 'nor...
# 1437  {'state': 'definitive', 'nbtrace_region': 'nor...
# 1438  {'state': 'definitive', 'nbtrace_region': 'nor...
# 1439  {'state': 'definitive', 'nbtrace_region': 'nor...
#
# [1440 rows x 7 columns]
